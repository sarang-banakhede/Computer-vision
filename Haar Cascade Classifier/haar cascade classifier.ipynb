# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Define our imshow function 
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %% [markdown]
# FACE detection

# %%
face_classifier= cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
image= cv2.imread('Artifacts\Images\img.jpg')
gray= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces= face_classifier.detectMultiScale(gray, scaleFactor=1.1, minNeighbors= 4)
for (x,y,w,h) in faces:
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
imshow('Face Detection', image)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\I'
# <>:2: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\saran\AppData\Local\Temp\ipykernel_14392\2310614967.py:2: SyntaxWarning: invalid escape sequence '\I'
#   image= cv2.imread('Artifacts\Images\img.jpg')

# %% [markdown]
# Eyes detection

# %%
face_classifier= cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_classifier= cv2.CascadeClassifier('haarcascade_eye.xml')
image= cv2.imread('Artifacts\Images\jony.png')
gray= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces= face_classifier.detectMultiScale(gray, scaleFactor=1.1, minNeighbors= 4)
for (x,y,w,h) in faces:
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
    roi_gray= gray[y:y+h, x:x+w]
    roi_color= image[y:y+h, x:x+w]
    eyes= eye_classifier.detectMultiScale(roi_gray, scaleFactor=1.1, minNeighbors= 30)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color, (ex,ey), (ex+ew, ey+eh), (255,0,0), 2)
imshow('Eye Detection', image)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\I'
# <>:3: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\saran\AppData\Local\Temp\ipykernel_14392\4021572507.py:3: SyntaxWarning: invalid escape sequence '\I'
#   image= cv2.imread('Artifacts\Images\jony.png')
